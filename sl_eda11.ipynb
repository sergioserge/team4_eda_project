# %%
# https://planningpokeronline.com/MXQVEjbbfB8nLBa1ZPlb
from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 1000})

# %%
import pandas as pd

# %%
orders = pd.read_excel('data/Muesli Project raw data 21-3.xlsx', 0, header=1)
order_process = pd.read_excel('data/Muesli Project raw data 21-3.xlsx', 1) 
intern_data = pd.read_excel('data/Muesli Project raw data 21-3.xlsx', 2) 
campaign_data = pd.read_excel('data/Muesli Project raw data 21-3.xlsx', 3)

# %%
df_list = [orders, order_process, intern_data, campaign_data]

df_all = pd.merge(orders, order_process, how='left', on='Order ID')
df_all = pd.merge(df_all, intern_data, how='left', on='Order ID')
df_all = pd.merge(df_all, campaign_data, how='left', on='Order ID')

df = pd.merge(orders, order_process, how='right', on='Order ID')

# %%
display(df_all.head())
display(df.head())

display(df_all.info())
display(df.info())
# Out:
#          Order ID Order Date_x Customer ID Customer Name_x Origin Channel  \
# 0  CA-2017-103800   2017-01-03    DP-13000   Darren Powers          Email
# 1  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 2  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 3  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 4  CA-2017-141817   2017-01-05    MB-18085      Mick Brown          Email
#
#   Country/Region          City         State  Postal Code   Region  ...  \
# 0  United States       Houston         Texas      77095.0  Central  ...
# 1  United States    Naperville      Illinois      60540.0  Central  ...
# 2  United States    Naperville      Illinois      60540.0  Central  ...
# 3  United States    Naperville      Illinois      60540.0  Central  ...
# 4  United States  Philadelphia  Pennsylvania      19143.0     East  ...
#
#          Sub-Category       Product ID Quantity  Order Date_y  \
# ...

# %%
print(orders[['Order ID']].nunique()) # 5009 unique data points
print(orders.info())
print(order_process[['Order ID']].nunique()) # 3002 unique - should be ca. 2000 more
print(order_process.info())
# only 3003 datapoints
print(intern_data.info())
# can we approximate the rest of the datapoints?
print(campaign_data.info())
# Out:
# Order ID    5009
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9994 non-null   object
#  1   Order Date      9994 non-null   datetime64[ns]
#  2   Customer ID     9994 non-null   object
#  3   Customer Name   9994 non-null   object
#  4   Origin Channel  9994 non-null   object
#  5   Country/Region  9994 non-null   object
#  6   City            9994 non-null   object
#  7   State           9994 non-null   object
#  8   Postal Code     9983 non-null   float64
#  9   Region          9994 non-null   object
#  10  Category        9994 non-null   object
#  11  Sub-Category    9994 non-null   object
#  12  Product ID      9994 non-null   object
#  13  Quantity        9994 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(11)
# memory usage: 1.1+ MB
# None
# Order ID    3002
# ...

# %%
print(order_process[['Order ID']].nunique()) # 3002 unique - should be ca. 2000 more
print(order_process.info())
# only 3003 datapoints
# Out:
# Order ID    3002
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3003 entries, 0 to 3002
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            3003 non-null   object
#  1   Order Date          3003 non-null   datetime64[ns]
#  2   On Truck Scan Date  3003 non-null   datetime64[ns]
#  3   Processing Mode     3003 non-null   object
# dtypes: datetime64[ns](2), object(2)
# memory usage: 94.0+ KB
# None

# %%
print(intern_data.info())
# can we approximate the rest of the datapoints?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            290 non-null    object
#  1   Ready to Ship Date  290 non-null    datetime64[ns]
#  2   Pickup Date         290 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 6.9+ KB
# None

# %%
print(campaign_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           333 non-null    object
#  1   Arrival Scan Date  333 non-null    datetime64[ns]
#  2   Customer Name      333 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 7.9+ KB
# None

# %%
df
# Out:
#             Order ID Order Date_x Customer ID      Customer Name  \
# 0     CA-2019-160304   2019-01-02    BM-11575      Brendan Murry
# 1     CA-2019-160304   2019-01-02    BM-11575      Brendan Murry
# 2     CA-2019-125206   2019-01-03    LR-16915       Lena Radford
# 3     US-2019-116365   2019-01-03    CA-12310  Christine Abelman
# 4     US-2019-116365   2019-01-03    CA-12310  Christine Abelman
# ...              ...          ...         ...                ...
# 5896  CA-2020-143259   2020-12-30    PO-18865  Patrick O'Donnell
# 5897  CA-2020-143259   2020-12-30    PO-18865  Patrick O'Donnell
# 5898  CA-2020-115427   2020-12-30    EB-13975         Erica Bern
# 5899  CA-2020-115427   2020-12-30    EB-13975         Erica Bern
# 5900  CA-2020-156720   2020-12-30    JM-15580      Jill Matthias
#
#      Origin Channel Country/Region           City       State  Postal Code  \
# 0             Sales  United States   Gaithersburg    Maryland      20877.0
# ...

# %%
drop_list = ['customer_name', 'country/region', 'city', 'state', 'postacl_code', 'region', ]

# %%
import datetime as dt

df['dur'] = df['On Truck Scan Date'] - df['Order Date_x']
# df['datetime_colum'].apply(lambda x:x.toordinal())
df['dur'].apply(lambda x: x.days)
df['dur'].apply(lambda x: int(x))
df[['dur']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d7/59nvcj7d4xv237dn13b9ltd80000gn/T/ipykernel_2237/880799767.py in <module>
#       4 # df['datetime_colum'].apply(lambda x:x.toordinal())
#       5 df['dur'].apply(lambda x: x.days)
# ----> 6 df['dur'].apply(lambda x: int(x))
#       7 df[['dur']]
#
# /usr/local/Caskroom/miniconda/base/envs/eda_env/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/Caskroom/miniconda/base/envs/eda_env/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
# ...

# %%
df['dur'].describe()
# Out:
# count    5901.000000
# mean        6.119641
# std         2.509086
# min         0.000000
# 25%         5.000000
# 50%         7.000000
# 75%         8.000000
# max        12.000000
# Name: dur, dtype: float64
