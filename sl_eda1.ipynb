# %%
import pandas as pd

EXCEL_FILE = "data/Muesli Project raw data 21-3.xlsx"

def import_xls(file, sheet, header=0):
    df = pd.read_excel(file, sheet_name = sheet, header=header)
    return df

# %%
df_orders = import_xls(EXCEL_FILE, "Orders", header=1)
df_order_process = import_xls(EXCEL_FILE, "Order Process Data")
df_intern = import_xls(EXCEL_FILE, "InternData Study")
df_campaign = import_xls(EXCEL_FILE, "Campaign Data")
df_list = [df_orders, df_order_process, df_intern, df_campaign]

# %%
def column_rename(df):
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace(' ', '_')
    return df

# %%
for df in df_list:
    column_rename(df)
    display(df)
# Out:
#             order_id order_date customer_id      customer_name origin_channel  \
# 0     CA-2017-103800 2017-01-03    DP-13000      Darren Powers          Email
# 1     CA-2017-112326 2017-01-04    PO-19195      Phillina Ober       Facebook
# 2     CA-2017-112326 2017-01-04    PO-19195      Phillina Ober       Facebook
# 3     CA-2017-112326 2017-01-04    PO-19195      Phillina Ober       Facebook
# 4     CA-2017-141817 2017-01-05    MB-18085         Mick Brown          Email
# ...              ...        ...         ...                ...            ...
# 9989  CA-2020-126221 2020-12-30    CC-12430        Chuck Clark       Facebook
# 9990  CA-2020-143259 2020-12-30    PO-18865  Patrick O'Donnell          Email
# 9991  CA-2020-143259 2020-12-30    PO-18865  Patrick O'Donnell          Email
# 9992  CA-2020-143259 2020-12-30    PO-18865  Patrick O'Donnell          Email
# 9993  CA-2020-156720 2020-12-30    JM-15580      Jill Matthias          Email
#
#      country/region           city         state  postal_code   region  \
# 0     United States        Houston         Texas      77095.0  Central
# 1     United States     Naperville      Illinois      60540.0  Central
# 2     United States     Naperville      Illinois      60540.0  Central
# 3     United States     Naperville      Illinois      60540.0  Central
# 4     United States   Philadelphia  Pennsylvania      19143.0     East
# ...             ...            ...           ...          ...      ...
# 9989  United States       Columbus       Indiana      47201.0  Central
# 9990  United States  New York City      New York      10009.0     East
# 9991  United States  New York City      New York      10009.0     East
# 9992  United States  New York City      New York      10009.0     East
# 9993  United States       Loveland      Colorado      80538.0     West
#
#                      category        sub-category       product_id  quantity
# 0                Power Muesli       Nuts and more  OFF-PA-10000174       2.0
# 1                Power Muesli  No Taste All Power  OFF-LA-10003223       3.0
# 2                Power Muesli           Steel Cut  OFF-ST-10002743       3.0
# 3                Power Muesli   Super Fibre Boost  OFF-BI-10004094       2.0
# 4                Power Muesli  Super Mega Protein  OFF-AR-10003478       3.0
# ...                       ...                 ...              ...       ...
# 9989             Power Muesli        Mega Protein  OFF-AP-10002457       2.0
# 9990  Special Projects Muesil           Only Oats  TEC-PH-10004774       7.0
# 9991             Power Muesli   Super Fibre Boost  OFF-BI-10003684       3.0
# 9992           Toasted Muesli          With Fruit  FUR-BO-10003441       4.0
# 9993             Power Muesli     Maple Sweetened  OFF-FA-10003472       3.0
#
# [9994 rows x 14 columns]
#             order_id order_date on_truck_scan_date      processing_mode
# 0     CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 1     CA-2019-125206 2019-01-03         2019-01-07              Express
# 2     US-2019-116365 2019-01-03         2019-01-09  Standard Processing
# 3     CA-2019-105207 2019-01-03         2019-01-09  Standard Processing
# 4     US-2019-164630 2019-01-04         2019-01-11  Standard Processing
# ...              ...        ...                ...                  ...
# 2998  US-2020-158526 2020-12-29         2021-01-04  Standard Processing
# 2999  CA-2020-126221 2020-12-30         2021-01-06  Standard Processing
# 3000  CA-2020-143259 2020-12-30         2021-01-06  Standard Processing
# 3001  CA-2020-115427 2020-12-30         2021-01-06  Standard Processing
# 3002  CA-2020-156720 2020-12-30         2021-01-06  Standard Processing
#
# [3003 rows x 4 columns]
#            order_id ready_to_ship_date pickup_date
# 0    CA-2019-116540         2019-09-02  2019-09-03
# 1    CA-2019-116540         2019-09-02  2019-09-03
# 2    CA-2019-129847         2019-09-04  2019-09-04
# 3    CA-2019-129630         2019-09-04  2019-09-04
# 4    CA-2019-106278         2019-09-05  2019-09-06
# ..              ...                ...         ...
# 285  CA-2020-105333         2020-12-04  2020-12-07
# 286  CA-2020-105333         2020-12-04  2020-12-07
# 287  US-2020-110576         2020-12-04  2020-12-07
# 288  CA-2020-119305         2020-12-04  2020-12-07
# 289  CA-2020-142090         2020-12-07  2020-12-09
#
# [290 rows x 3 columns]
#            order_id arrival_scan_date     customer_name
# 0    CA-2019-109666        2019-05-03      Kunst Miller
# 1    CA-2019-138933        2019-05-03       Jack Lebron
# 2    CA-2019-130001        2019-05-03  Heather Kirkland
# 3    CA-2019-113061        2019-05-06         Ed Ludwig
# 4    CA-2019-162138        2019-05-06       Grace Kelly
# ..              ...               ...               ...
# 328  CA-2020-129707        2020-05-08      Larry Hughes
# 329  CA-2020-125381        2020-05-08  Speros Goranitis
# 330  CA-2020-141733        2020-05-15       Rick Wilson
# 331  US-2020-104451        2020-05-15    Michelle Moray
# 332  US-2020-139647        2020-05-15      Todd Sumrall
#
# [333 rows x 3 columns]

# %%
# for df in df_list:
#     display(df.info())
#     display(df.describe())

# %%
# 
num_unique_orders = df_orders['order_id'].nunique()
num_unique_order_process = df_order_process['order_id'].nunique()
num_unique_dif = num_unique_orders - num_unique_order_process
print("We don't have all the order ids in the order process dataset. \nContrary to company assumptions there is a  difference", num_unique_dif)

# Nothing found 
# ~ = not in


df_order_process[~df_order_process['order_id'].isin(df_orders['order_id'])].count()
# Out:
# We don't have all the order ids in the order process dataset.
# Contrary to company assumptions there is a  difference 2007
# order_id              0
# order_date            0
# on_truck_scan_date    0
# processing_mode       0
# dtype: int64

# %%
df_list = [df_orders, df_order_process, df_intern, df_campaign]

df_all = pd.merge(df_orders, df_order_process, how='left', on='order_id')
df_all = pd.merge(df_all, df_intern, how='left', on='order_id')
df_all = pd.merge(df_all, df_campaign, how='left', on='order_id')

df = pd.merge(df_orders, df_order_process, how='inner', on='order_id')

# %%
# Doublecheck if we have the same amount of unique order ids in merged df as in the df_order_process
display(df['order_id'].nunique())

display(df_all.head())
display(df.head())

display(df_all.info())
display(df.info())
# Out:
# 3002
#          order_id order_date_x customer_id customer_name_x origin_channel  \
# 0  CA-2017-103800   2017-01-03    DP-13000   Darren Powers          Email
# 1  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 2  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 3  CA-2017-112326   2017-01-04    PO-19195   Phillina Ober       Facebook
# 4  CA-2017-141817   2017-01-05    MB-18085      Mick Brown          Email
#
#   country/region          city         state  postal_code   region  ...  \
# 0  United States       Houston         Texas      77095.0  Central  ...
# 1  United States    Naperville      Illinois      60540.0  Central  ...
# 2  United States    Naperville      Illinois      60540.0  Central  ...
# 3  United States    Naperville      Illinois      60540.0  Central  ...
# 4  United States  Philadelphia  Pennsylvania      19143.0     East  ...
#
#          sub-category       product_id quantity  order_date_y  \
# 0       Nuts and more  OFF-PA-10000174      2.0           NaT
# 1  No Taste All Power  OFF-LA-10003223      3.0           NaT
# 2           Steel Cut  OFF-ST-10002743      3.0           NaT
# 3   Super Fibre Boost  OFF-BI-10004094      2.0           NaT
# 4  Super Mega Protein  OFF-AR-10003478      3.0           NaT
#
#   on_truck_scan_date processing_mode ready_to_ship_date pickup_date  \
# 0                NaT             NaN                NaT         NaT
# 1                NaT             NaN                NaT         NaT
# 2                NaT             NaN                NaT         NaT
# 3                NaT             NaN                NaT         NaT
# 4                NaT             NaN                NaT         NaT
#
#   arrival_scan_date customer_name_y
# 0               NaT             NaN
# 1               NaT             NaN
# 2               NaT             NaN
# 3               NaT             NaN
# 4               NaT             NaN
#
# [5 rows x 21 columns]
#          order_id order_date_x customer_id  customer_name origin_channel  \
# 0  CA-2019-160304   2019-01-02    BM-11575  Brendan Murry          Sales
# 1  CA-2019-160304   2019-01-02    BM-11575  Brendan Murry          Sales
# 2  CA-2019-105207   2019-01-03    BO-11350  Bill Overfelt          Sales
# 3  CA-2019-105207   2019-01-03    BO-11350  Bill Overfelt          Sales
# 4  CA-2019-125206   2019-01-03    LR-16915   Lena Radford          Email
#
#   country/region          city       state  postal_code   region  \
# 0  United States  Gaithersburg    Maryland      20877.0     East
# 1  United States  Gaithersburg    Maryland      20877.0     East
# 2  United States  Broken Arrow    Oklahoma      74012.0  Central
# 3  United States  Broken Arrow    Oklahoma      74012.0  Central
# 4  United States   Los Angeles  California      90045.0     West
#
#                   category       sub-category       product_id  quantity  \
# 0  Special Projects Muesil          Only Oats  TEC-PH-10000455       2.0
# 1           Toasted Muesli         With Fruit  FUR-BO-10004709       3.0
# 2             Power Muesli  Super Fibre Boost  OFF-BI-10004364       2.0
# 3           Toasted Muesli          Sweetened  FUR-TA-10000617       7.0
# 4             Power Muesli          Steel Cut  OFF-ST-10003692       2.0
#
#   order_date_y on_truck_scan_date      processing_mode
# 0   2019-01-02         2019-01-09  Standard Processing
# 1   2019-01-02         2019-01-09  Standard Processing
# 2   2019-01-03         2019-01-09  Standard Processing
# 3   2019-01-03         2019-01-09  Standard Processing
# 4   2019-01-03         2019-01-07              Express
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10331 entries, 0 to 10330
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            10331 non-null  object
#  1   order_date_x        10331 non-null  datetime64[ns]
#  2   customer_id         10331 non-null  object
#  3   customer_name_x     10331 non-null  object
#  4   origin_channel      10331 non-null  object
#  5   country/region      10331 non-null  object
#  6   city                10331 non-null  object
#  7   state               10331 non-null  object
#  8   postal_code         10320 non-null  float64
#  9   region              10331 non-null  object
#  10  category            10331 non-null  object
#  11  sub-category        10331 non-null  object
#  12  product_id          10331 non-null  object
#  13  quantity            10331 non-null  float64
#  14  order_date_y        6236 non-null   datetime64[ns]
#  15  on_truck_scan_date  6236 non-null   datetime64[ns]
#  16  processing_mode     6236 non-null   object
#  17  ready_to_ship_date  753 non-null    datetime64[ns]
#  18  pickup_date         753 non-null    datetime64[ns]
#  19  arrival_scan_date   711 non-null    datetime64[ns]
#  20  customer_name_y     711 non-null    object
# dtypes: datetime64[ns](6), float64(2), object(13)
# memory usage: 1.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5901 entries, 0 to 5900
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            5901 non-null   object
#  1   order_date_x        5901 non-null   datetime64[ns]
#  2   customer_id         5901 non-null   object
#  3   customer_name       5901 non-null   object
#  4   origin_channel      5901 non-null   object
#  5   country/region      5901 non-null   object
#  6   city                5901 non-null   object
#  7   state               5901 non-null   object
#  8   postal_code         5892 non-null   float64
#  9   region              5901 non-null   object
#  10  category            5901 non-null   object
#  11  sub-category        5901 non-null   object
#  12  product_id          5901 non-null   object
#  13  quantity            5901 non-null   float64
#  14  order_date_y        5901 non-null   datetime64[ns]
#  15  on_truck_scan_date  5901 non-null   datetime64[ns]
#  16  processing_mode     5901 non-null   object
# dtypes: datetime64[ns](3), float64(2), object(12)
# memory usage: 829.8+ KB
# None

# %%
df["order_id"].nunique()
drop_list = ['customer_name', 'country/region', 'city', 'state', 'postal_code', 'region'] 
df = df.drop(drop_list, axis=1)

# %%
display(df.head(10))
# Out:
#          order_id order_date_x customer_id origin_channel  \
# 0  CA-2019-160304   2019-01-02    BM-11575          Sales
# 1  CA-2019-160304   2019-01-02    BM-11575          Sales
# 2  CA-2019-105207   2019-01-03    BO-11350          Sales
# 3  CA-2019-105207   2019-01-03    BO-11350          Sales
# 4  CA-2019-125206   2019-01-03    LR-16915          Email
# 5  US-2019-116365   2019-01-03    CA-12310          Sales
# 6  US-2019-116365   2019-01-03    CA-12310          Sales
# 7  US-2019-116365   2019-01-03    CA-12310          Sales
# 8  CA-2019-158211   2019-01-04    BP-11185          Sales
# 9  CA-2019-158211   2019-01-04    BP-11185          Sales
#
#                   category        sub-category       product_id  quantity  \
# 0  Special Projects Muesil           Only Oats  TEC-PH-10000455       2.0
# 1           Toasted Muesli          With Fruit  FUR-BO-10004709       3.0
# 2             Power Muesli   Super Fibre Boost  OFF-BI-10004364       2.0
# 3           Toasted Muesli           Sweetened  FUR-TA-10000617       7.0
# 4             Power Muesli           Steel Cut  OFF-ST-10003692       2.0
# 5  Special Projects Muesil         Gluten Free  TEC-AC-10002217       2.0
# 6  Special Projects Muesil         Gluten Free  TEC-AC-10002942       3.0
# 7  Special Projects Muesil           Only Oats  TEC-PH-10002890       5.0
# 8             Power Muesli   Super Fibre Boost  OFF-BI-10002026       6.0
# 9             Power Muesli  Super Mega Protein  OFF-AR-10004078       1.0
#
#   order_date_y on_truck_scan_date      processing_mode
# 0   2019-01-02         2019-01-09  Standard Processing
# 1   2019-01-02         2019-01-09  Standard Processing
# 2   2019-01-03         2019-01-09  Standard Processing
# 3   2019-01-03         2019-01-09  Standard Processing
# 4   2019-01-03         2019-01-07              Express
# 5   2019-01-03         2019-01-09  Standard Processing
# 6   2019-01-03         2019-01-09  Standard Processing
# 7   2019-01-03         2019-01-09  Standard Processing
# 8   2019-01-04         2019-01-09  Standard Processing
# 9   2019-01-04         2019-01-09  Standard Processing

# %%
df[df["order_date_x"] != df["order_date_y"]]
df[df["order_date_x"] == df["order_date_y"]].count()
# Out:
# order_id              5901
# order_date_x          5901
# customer_id           5901
# origin_channel        5901
# category              5901
# sub-category          5901
# product_id            5901
# quantity              5901
# order_date_y          5901
# on_truck_scan_date    5901
# processing_mode       5901
# dtype: int64

# %%
df.drop("order_date_y", axis=1, inplace =True)

# %%
df.rename(columns = {"order_date_x": "order_date"}, inplace=True)
display(df)
# Out:
#             order_id order_date customer_id origin_channel  \
# 0     CA-2019-160304 2019-01-02    BM-11575          Sales
# 1     CA-2019-160304 2019-01-02    BM-11575          Sales
# 2     CA-2019-105207 2019-01-03    BO-11350          Sales
# 3     CA-2019-105207 2019-01-03    BO-11350          Sales
# 4     CA-2019-125206 2019-01-03    LR-16915          Email
# ...              ...        ...         ...            ...
# 5896  CA-2020-126221 2020-12-30    CC-12430       Facebook
# 5897  CA-2020-143259 2020-12-30    PO-18865          Email
# 5898  CA-2020-143259 2020-12-30    PO-18865          Email
# 5899  CA-2020-143259 2020-12-30    PO-18865          Email
# 5900  CA-2020-156720 2020-12-30    JM-15580          Email
#
#                      category       sub-category       product_id  quantity  \
# 0     Special Projects Muesil          Only Oats  TEC-PH-10000455       2.0
# 1              Toasted Muesli         With Fruit  FUR-BO-10004709       3.0
# 2                Power Muesli  Super Fibre Boost  OFF-BI-10004364       2.0
# 3              Toasted Muesli          Sweetened  FUR-TA-10000617       7.0
# 4                Power Muesli          Steel Cut  OFF-ST-10003692       2.0
# ...                       ...                ...              ...       ...
# 5896             Power Muesli       Mega Protein  OFF-AP-10002457       2.0
# 5897  Special Projects Muesil          Only Oats  TEC-PH-10004774       7.0
# 5898             Power Muesli  Super Fibre Boost  OFF-BI-10003684       3.0
# 5899           Toasted Muesli         With Fruit  FUR-BO-10003441       4.0
# 5900             Power Muesli    Maple Sweetened  OFF-FA-10003472       3.0
#
#      on_truck_scan_date      processing_mode
# 0            2019-01-09  Standard Processing
# 1            2019-01-09  Standard Processing
# 2            2019-01-09  Standard Processing
# 3            2019-01-09  Standard Processing
# 4            2019-01-07              Express
# ...                 ...                  ...
# 5896         2021-01-06  Standard Processing
# 5897         2021-01-06  Standard Processing
# 5898         2021-01-06  Standard Processing
# 5899         2021-01-06  Standard Processing
# 5900         2021-01-06  Standard Processing
#
# [5901 rows x 10 columns]

# %%
df["pretransportation_duration"] = df["on_truck_scan_date"] - df["order_date"]
df["pretransportation_duration"] = df["pretransportation_duration"].dt.days

# %%
df.describe()
# Out:
#           quantity  pretransportation_duration
# count  5901.000000                 5901.000000
# mean      3.782071                    6.119641
# std       2.212742                    2.509086
# min       1.000000                    0.000000
# 25%       2.000000                    5.000000
# 50%       3.000000                    7.000000
# 75%       5.000000                    8.000000
# max      14.000000                   12.000000

# %%
df['weekday'] = df['order_date'].dt.weekday

# %%
df.head()
# Out:
#          order_id order_date customer_id origin_channel  \
# 0  CA-2019-160304 2019-01-02    BM-11575          Sales
# 1  CA-2019-160304 2019-01-02    BM-11575          Sales
# 2  CA-2019-105207 2019-01-03    BO-11350          Sales
# 3  CA-2019-105207 2019-01-03    BO-11350          Sales
# 4  CA-2019-125206 2019-01-03    LR-16915          Email
#
#                   category       sub-category       product_id  quantity  \
# 0  Special Projects Muesil          Only Oats  TEC-PH-10000455       2.0
# 1           Toasted Muesli         With Fruit  FUR-BO-10004709       3.0
# 2             Power Muesli  Super Fibre Boost  OFF-BI-10004364       2.0
# 3           Toasted Muesli          Sweetened  FUR-TA-10000617       7.0
# 4             Power Muesli          Steel Cut  OFF-ST-10003692       2.0
#
#   on_truck_scan_date      processing_mode  pretransportation_duration  weekday
# 0         2019-01-09  Standard Processing                           7        2
# 1         2019-01-09  Standard Processing                           7        2
# 2         2019-01-09  Standard Processing                           6        3
# 3         2019-01-09  Standard Processing                           6        3
# 4         2019-01-07              Express                           4        3

# %%
# Create two labels of delivery date depending on express/ non/express processing(see flowchart)
same_arrival_day = [0, 2, 5, 6]
different_arrival_day = [1, 3, 4]

# Devide the dataframe into two groups with regard to these labels
same_day = df[df['weekday'].isin(same_arrival_day)]
different_days = df[df['weekday'].isin(different_arrival_day)]

# Doublecheck if the division is done correctly
check_difference = df['order_id'].count() - same_day['order_id'].count() - different_days['order_id'].count()
display(f'The Difference should be zero: ', check_difference)
# Out:
# 'The Difference should be zero: '
# 0

# %%
# Compare descriptive statistics of each dataset
display('Same Day' ,same_day.describe())
display('Different Day' ,different_days.describe())

# Comparison:
# quantities: shows very equal distribution, though same_day orders are from 4 days and different days are from 3
 # Tuesday, Thursday and Friday are days with a lot of incoming orders
# Out:
# 'Same Day'
#           quantity  pretransportation_duration      weekday
# count  2932.000000                 2932.000000  2932.000000
# mean      3.760232                    6.438608     2.479877
# std       2.180717                    2.638581     2.308353
# min       1.000000                    0.000000     0.000000
# 25%       2.000000                    5.000000     0.000000
# 50%       3.000000                    7.000000     2.000000
# 75%       5.000000                    9.000000     5.000000
# max      14.000000                   12.000000     6.000000
# 'Different Day'
#           quantity  pretransportation_duration      weekday
# count  2969.000000                 2969.000000  2969.000000
# mean      3.803638                    5.804648     2.604244
# std       2.244079                    2.332292     1.237605
# min       1.000000                    0.000000     1.000000
# 25%       2.000000                    5.000000     1.000000
# 50%       3.000000                    6.000000     3.000000
# 75%       5.000000                    8.000000     4.000000
# max      14.000000                   11.000000     4.000000

# %%
# We should analyse and visualize the days with the most incoming orders
# e.g. Barchart of orderquantities and weekdays

# Combine pretransportation_duration with processing_mode-column

# %%
df['pretransportation_duration'].describe()
# Out:
# count    5901.000000
# mean        6.119641
# std         2.509086
# min         0.000000
# 25%         5.000000
# 50%         7.000000
# 75%         8.000000
# max        12.000000
# Name: pretransportation_duration, dtype: float64

# %%
standard_pre = df[df['processing_mode']=='Standard Processing']['pretransportation_duration']
express_pre = df[df['processing_mode']=='Express']['pretransportation_duration']

display('standard_pre ', standard_pre.describe())
display('express_pre ', express_pre.describe())
# Out:
# 'standard_pre '
# count    4596.000000
# mean        7.127502
# std         1.651674
# min         2.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        12.000000
# Name: pretransportation_duration, dtype: float64
# 'express_pre '
# count    1305.000000
# mean        2.570115
# std         1.637800
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max         6.000000
# Name: pretransportation_duration, dtype: float64

# %%
# add column with weekday

df['weekday'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Select only orders which would arrive before weekend --> only monday with standard preprocessing
standard_before_weekend = df[df['weekday'] == 0 & df['processing_mode'].isin(['Standard Processing'])]
display('standard_before_weekend', standard_before_weekend['pretransportation_duration'].describe())
display('standard_before_weekend', standard_before_weekend.mode())

# Select only orders which would arrive before weekend --> only monday and tuesday with express preprocessing
express_before_weekend = df[df['weekday'].isin([0, 1]) & df['processing_mode'].isin(['Express'])]
display('express_before_weekend', express_before_weekend['pretransportation_duration'].describe())
display('express_before_weekend', express_before_weekend.mode())

# only data where 1, 2 days max is accomplished(how long does it take until on transport when truck dates are not a problem)
# Express Tuesday+Thursday
# Standard Monday + Wednesday
# Out:
# 'standard_before_weekend'
# count    970.000000
# mean       6.384536
# std        2.890068
# min        0.000000
# 25%        4.000000
# 50%        7.000000
# 75%        9.000000
# max       11.000000
# Name: pretransportation_duration, dtype: float64
# 'standard_before_weekend'
#          order_id order_date customer_id origin_channel      category  \
# 0  CA-2019-111682 2019-09-02    JE-15715          Email  Power Muesli
# 1  CA-2019-135776        NaT         NaN            NaN           NaN
# 2  CA-2020-119284        NaT         NaN            NaN           NaN
# 3  CA-2020-166093        NaT         NaN            NaN           NaN
# 4             NaN        NaT         NaN            NaN           NaN
# 5             NaN        NaT         NaN            NaN           NaN
# 6             NaN        NaT         NaN            NaN           NaN
#
#         sub-category       product_id  quantity on_truck_scan_date  \
# 0  Super Fibre Boost  FUR-CH-10000454       2.0         2019-11-20
# 1                NaN  OFF-AR-10000390       NaN         2020-09-16
# 2                NaN  OFF-BI-10004236       NaN                NaT
# 3                NaN  OFF-BI-10004654       NaN                NaT
# 4                NaN  OFF-LA-10001297       NaN                NaT
# 5                NaN  TEC-AC-10003033       NaN                NaT
# 6                NaN  TEC-AC-10004510       NaN                NaT
#
#        processing_mode  pretransportation_duration  weekday
# 0  Standard Processing                         9.0      0.0
# 1                  NaN                         NaN      NaN
# 2                  NaN                         NaN      NaN
# 3                  NaN                         NaN      NaN
# 4                  NaN                         NaN      NaN
# 5                  NaN                         NaN      NaN
# 6                  NaN                         NaN      NaN
# 'express_before_weekend'
# count    436.000000
# mean       2.103211
# std        1.201872
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: pretransportation_duration, dtype: float64
# 'express_before_weekend'
#          order_id order_date customer_id origin_channel      category  \
# 0  US-2019-108504 2020-09-14    PP-18955          Email  Power Muesli
# 1             NaN 2020-09-29         NaN            NaN           NaN
#
#     sub-category       product_id  quantity on_truck_scan_date  \
# 0  Nuts and more  TEC-AC-10003832       2.0         2020-10-02
# 1            NaN              NaN       NaN                NaT
#
#   processing_mode  pretransportation_duration  weekday
# 0         Express                         2.0      0.0
# 1             NaN                         NaN      NaN

# %%
# KPI:
# Company Level
# Average delivery duration (standard): now --> goal
# Average delivery duration (express): now --> goal
# --> stacked barchart from order to warehouse to delivery(process issues not relevant)

# Processing Level
# Average processing duration (standard): now --> goal
# Average processing duration (express): now --> goal 
# --> visualization (process issues not relevant, besides delivery)

# Warehouse Level
# Average warehouse duration (standard): now --> goal
# Average warehouse duration (express): now --> goal 
# --> visualization (all process issues are relevant)
